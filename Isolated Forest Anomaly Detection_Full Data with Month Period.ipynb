# %% [markdown]
# ## Isolated Forest for Detecting Financial Anomalies

# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest
from sklearn.datasets import make_classification

# %%
# Columns to keep
columns = ['amtdb',
 'category',
 'subcategory',
 'fdb_commonname',
 'amtcr',
 'brnid',
 'brnmisc7',
 'altdept',
 'amtbalance',
 'date',
 'department',
 'type',
 'typ_text',]

# %%
# Read the file
df = pd.read_excel("~/Desktop/Data/df.xlsx", usecols=columns)
df.head(5)
# Out:
#    brnid   date     type  amtdb       amtcr  amtbalance department  \
# 0    200  45382  Expense    0.0   10.000000  -10.000000  Corporate
# 1    200  45351  Expense   10.0    0.000000   10.000000  Corporate
# 2    200  45504  Expense    0.0  155.000000 -155.000000  Corporate
# 3    200  45382  Expense    0.0  853.549988 -853.549988  Corporate
# 4    200  45504  Expense    0.0  900.000000 -900.000000  Corporate
#
#             altdept typ_text   category        subcategory     fdb_commonname  \
# 0  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
# 1  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
# 2  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
# 3  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
# 4  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
#
#          brnmisc7
# 0  Corporate LATC
# 1  Corporate LATC
# 2  Corporate LATC
# 3  Corporate LATC
# 4  Corporate LATC

# %%
# Convert column date into the dates
df['date'] = pd.to_datetime(df['date'], origin='1899-12-30', unit='D')
df.head(5)
# Out:
#    brnid       date     type  amtdb       amtcr  amtbalance department  \
# 0    200 2024-03-31  Expense    0.0   10.000000  -10.000000  Corporate
# 1    200 2024-02-29  Expense   10.0    0.000000   10.000000  Corporate
# 2    200 2024-07-31  Expense    0.0  155.000000 -155.000000  Corporate
# 3    200 2024-03-31  Expense    0.0  853.549988 -853.549988  Corporate
# 4    200 2024-07-31  Expense    0.0  900.000000 -900.000000  Corporate
#
#             altdept typ_text   category        subcategory     fdb_commonname  \
# 0  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
# 1  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
# 2  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
# 3  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
# 4  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
#
#          brnmisc7
# 0  Corporate LATC
# 1  Corporate LATC
# 2  Corporate LATC
# 3  Corporate LATC
# 4  Corporate LATC

# %%
# Create columns for year and month from the date column
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month

# %%
# drop July 2024 data because it is incomplete
df = df.drop(df[(df['year'] == 2024) & (df['month'] == 7)].index)
df.head(5)
# Out:
#    brnid       date     type  amtdb        amtcr   amtbalance department  \
# 0    200 2024-03-31  Expense    0.0    10.000000   -10.000000  Corporate
# 1    200 2024-02-29  Expense   10.0     0.000000    10.000000  Corporate
# 3    200 2024-03-31  Expense    0.0   853.549988  -853.549988  Corporate
# 5    200 2024-03-31  Expense    0.0    55.000000   -55.000000  Corporate
# 6    200 2024-06-30  Expense    0.0  7138.649902 -7138.649902  Corporate
#
#             altdept typ_text   category        subcategory     fdb_commonname  \
# 0  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
# 1  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
# 3  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
# 5  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
# 6  Used Truck Sales  Expense  Personnel  Employee Benefits  Employee Benefits
#
#          brnmisc7  year  month
# 0  Corporate LATC  2024      3
# 1  Corporate LATC  2024      2
# 3  Corporate LATC  2024      3
# 5  Corporate LATC  2024      3
# 6  Corporate LATC  2024      6

# %% [markdown]
# ## Anomalies Detections

# %% [markdown]
# #### Date Preparation

# %%
# Create a copy of the dataframe
df_copy = df.copy()

# %%
# Sort the DataFrame by year (descending), brnid, fdb_commonname, and month (ascending)
df_1 = df_copy.sort_values(by=[
    'brnid', 'brnmisc7', 'department', 'altdept', 'typ_text', 'category', 
    'subcategory', 'fdb_commonname', 'year', 'amtbalance', 'month'
])

# Rearrange the columns in the specified order
columns_order = ['date', 'year', 'month', 'brnid', 'brnmisc7', 'department', 'altdept', 'type', 'typ_text', 'category', 'subcategory', 'fdb_commonname', 
                 'amtdb', 'amtcr', 'amtbalance']
df_1 = df_1[columns_order]
df_1 = df_1.reset_index(drop=True)
df_1.head(25)
# Out:
#          date  year  month  brnid        brnmisc7 department    altdept  \
# 0  2023-07-31  2023      7    200  Corporate LATC  Corporate  Corporate
# 1  2023-07-31  2023      7    200  Corporate LATC  Corporate  Corporate
# 2  2023-07-31  2023      7    200  Corporate LATC  Corporate  Corporate
# 3  2023-07-31  2023      7    200  Corporate LATC  Corporate  Corporate
# 4  2023-01-31  2023      1    200  Corporate LATC  Corporate  Corporate
# 5  2023-02-28  2023      2    200  Corporate LATC  Corporate  Corporate
# 6  2023-04-30  2023      4    200  Corporate LATC  Corporate  Corporate
# 7  2023-05-31  2023      5    200  Corporate LATC  Corporate  Corporate
# 8  2023-12-31  2023     12    200  Corporate LATC  Corporate  Corporate
# 9  2023-06-30  2023      6    200  Corporate LATC  Corporate  Corporate
# 10 2023-07-31  2023      7    200  Corporate LATC  Corporate  Corporate
# 11 2023-08-31  2023      8    200  Corporate LATC  Corporate  Corporate
# 12 2023-09-30  2023      9    200  Corporate LATC  Corporate  Corporate
# 13 2023-10-31  2023     10    200  Corporate LATC  Corporate  Corporate
# 14 2023-12-31  2023     12    200  Corporate LATC  Corporate  Corporate
# 15 2023-12-31  2023     12    200  Corporate LATC  Corporate  Corporate
# 16 2023-01-31  2023      1    200  Corporate LATC  Corporate  Corporate
# 17 2023-01-31  2023      1    200  Corporate LATC  Corporate  Corporate
# 18 2023-02-28  2023      2    200  Corporate LATC  Corporate  Corporate
# 19 2023-02-28  2023      2    200  Corporate LATC  Corporate  Corporate
# 20 2023-03-31  2023      3    200  Corporate LATC  Corporate  Corporate
# 21 2023-03-31  2023      3    200  Corporate LATC  Corporate  Corporate
# 22 2023-04-30  2023      4    200  Corporate LATC  Corporate  Corporate
# 23 2023-05-31  2023      5    200  Corporate LATC  Corporate  Corporate
# 24 2023-05-31  2023      5    200  Corporate LATC  Corporate  Corporate
#
#        type typ_text category   subcategory fdb_commonname  amtdb   amtcr  \
# 0   Expense  Expense    Fixed  Rent / Lease     Rent/Lease    0.0  6702.0
# 1   Expense  Expense    Fixed  Rent / Lease     Rent/Lease    0.0  6509.0
# 2   Expense  Expense    Fixed  Rent / Lease     Rent/Lease    0.0  1798.0
# 3   Expense  Expense    Fixed  Rent / Lease     Rent/Lease    0.0  1484.0
# 4   Expense  Expense    Fixed  Rent / Lease     Rent/Lease  245.0     0.0
# 5   Expense  Expense    Fixed  Rent / Lease     Rent/Lease  245.0     0.0
# 6   Expense  Expense    Fixed  Rent / Lease     Rent/Lease  245.0     0.0
# 7   Expense  Expense    Fixed  Rent / Lease     Rent/Lease  245.0     0.0
# 8   Expense  Expense    Fixed  Rent / Lease     Rent/Lease  245.0     0.0
# 9   Expense  Expense    Fixed  Rent / Lease     Rent/Lease  266.0     0.0
# 10  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  266.0     0.0
# 11  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  266.0     0.0
# 12  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  266.0     0.0
# 13  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  266.0     0.0
# 14  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  266.0     0.0
# 15  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  266.0     0.0
# 16  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  469.0     0.0
# 17  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  469.0     0.0
# 18  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  469.0     0.0
# 19  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  469.0     0.0
# 20  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  469.0     0.0
# 21  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  469.0     0.0
# 22  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  469.0     0.0
# 23  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  469.0     0.0
# 24  Expense  Expense    Fixed  Rent / Lease     Rent/Lease  469.0     0.0
#
#     amtbalance
# 0      -6702.0
# 1      -6509.0
# 2      -1798.0
# 3      -1484.0
# 4        245.0
# 5        245.0
# 6        245.0
# 7        245.0
# 8        245.0
# 9        266.0
# 10       266.0
# 11       266.0
# 12       266.0
# 13       266.0
# 14       266.0
# 15       266.0
# 16       469.0
# 17       469.0
# 18       469.0
# 19       469.0
# 20       469.0
# 21       469.0
# 22       469.0
# 23       469.0
# 24       469.0

# %%
#Group the dataframe with resepct to brnid and fdb_commonname save as df_grouped in data file to do abservation
grouped_df_1 = df_1.groupby(['brnid', 'fdb_commonname']).apply(lambda x: x)
grouped_df_1.head(25)
# df_1.groupby(['brnid', 'fdb_commonname']).apply(lambda x: x).to_excel("~/Desktop/Data/df_grouped.xlsx", index=False)
# Out:
# /var/folders/ld/1rz8qh_13jz1s4wm8s6pdhgm0000gn/T/ipykernel_79638/223004813.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_df_1 = df_1.groupby(['brnid', 'fdb_commonname']).apply(lambda x: x)
#                                            date  year  month  brnid  \
# brnid fdb_commonname
# 200   Building Repair and Maint 5103 2023-02-28  2023      2    200
#                                 5104 2023-04-30  2023      4    200
#                                 5105 2023-03-31  2023      3    200
#                                 5106 2023-10-31  2023     10    200
#                                 5107 2023-09-30  2023      9    200
#                                 5108 2023-11-30  2023     11    200
#                                 5109 2023-03-31  2023      3    200
#                                 5110 2023-01-31  2023      1    200
#                                 5111 2023-01-31  2023      1    200
#                                 5112 2024-04-30  2024      4    200
#                                 5113 2024-06-30  2024      6    200
#                                 5114 2024-06-30  2024      6    200
#                                 5115 2024-06-30  2024      6    200
#                                 5116 2024-05-31  2024      5    200
#                                 5117 2024-01-31  2024      1    200
#                                 5118 2024-04-30  2024      4    200
#                                 5266 2024-06-30  2024      6    200
#                                 5267 2024-06-30  2024      6    200
#                                 5268 2024-06-30  2024      6    200
#       Employee Benefits         394  2023-12-31  2023     12    200
#                                 395  2023-12-31  2023     12    200
#                                 396  2023-12-31  2023     12    200
#                                 397  2023-12-31  2023     12    200
#                                 398  2023-12-31  2023     12    200
#                                 399  2023-12-31  2023     12    200
#
#                                             brnmisc7 department    altdept  \
# brnid fdb_commonname
# 200   Building Repair and Maint 5103  Corporate LATC  Corporate  Corporate
#                                 5104  Corporate LATC  Corporate  Corporate
#                                 5105  Corporate LATC  Corporate  Corporate
#                                 5106  Corporate LATC  Corporate  Corporate
#                                 5107  Corporate LATC  Corporate  Corporate
#                                 5108  Corporate LATC  Corporate  Corporate
#                                 5109  Corporate LATC  Corporate  Corporate
#                                 5110  Corporate LATC  Corporate  Corporate
#                                 5111  Corporate LATC  Corporate  Corporate
#                                 5112  Corporate LATC  Corporate  Corporate
#                                 5113  Corporate LATC  Corporate  Corporate
#                                 5114  Corporate LATC  Corporate  Corporate
#                                 5115  Corporate LATC  Corporate  Corporate
#                                 5116  Corporate LATC  Corporate  Corporate
#                                 5117  Corporate LATC  Corporate  Corporate
#                                 5118  Corporate LATC  Corporate  Corporate
#                                 5266  Corporate LATC  Corporate    Service
#                                 5267  Corporate LATC  Corporate    Service
#                                 5268  Corporate LATC  Corporate    Service
#       Employee Benefits         394   Corporate LATC  Corporate  Corporate
#                                 395   Corporate LATC  Corporate  Corporate
#                                 396   Corporate LATC  Corporate  Corporate
#                                 397   Corporate LATC  Corporate  Corporate
#                                 398   Corporate LATC  Corporate  Corporate
#                                 399   Corporate LATC  Corporate  Corporate
#
#                                          type typ_text    category  \
# brnid fdb_commonname
# 200   Building Repair and Maint 5103  Expense  Expense  Semi-Fixed
#                                 5104  Expense  Expense  Semi-Fixed
#                                 5105  Expense  Expense  Semi-Fixed
#                                 5106  Expense  Expense  Semi-Fixed
#                                 5107  Expense  Expense  Semi-Fixed
#                                 5108  Expense  Expense  Semi-Fixed
#                                 5109  Expense  Expense  Semi-Fixed
#                                 5110  Expense  Expense  Semi-Fixed
#                                 5111  Expense  Expense  Semi-Fixed
#                                 5112  Expense  Expense  Semi-Fixed
#                                 5113  Expense  Expense  Semi-Fixed
#                                 5114  Expense  Expense  Semi-Fixed
#                                 5115  Expense  Expense  Semi-Fixed
#                                 5116  Expense  Expense  Semi-Fixed
#                                 5117  Expense  Expense  Semi-Fixed
#                                 5118  Expense  Expense  Semi-Fixed
#                                 5266  Expense  Expense  Semi-Fixed
#                                 5267  Expense  Expense  Semi-Fixed
#                                 5268  Expense  Expense  Semi-Fixed
#       Employee Benefits         394   Expense  Expense   Personnel
#                                 395   Expense  Expense   Personnel
#                                 396   Expense  Expense   Personnel
#                                 397   Expense  Expense   Personnel
#                                 398   Expense  Expense   Personnel
#                                 399   Expense  Expense   Personnel
#
#                                                      subcategory  \
# brnid fdb_commonname
# 200   Building Repair and Maint 5103  Bulding - Repairs / Maint.
#                                 5104  Bulding - Repairs / Maint.
#                                 5105  Bulding - Repairs / Maint.
#                                 5106  Bulding - Repairs / Maint.
#                                 5107  Bulding - Repairs / Maint.
#                                 5108  Bulding - Repairs / Maint.
#                                 5109  Bulding - Repairs / Maint.
#                                 5110  Bulding - Repairs / Maint.
#                                 5111  Bulding - Repairs / Maint.
#                                 5112  Bulding - Repairs / Maint.
#                                 5113  Bulding - Repairs / Maint.
#                                 5114  Bulding - Repairs / Maint.
#                                 5115  Bulding - Repairs / Maint.
#                                 5116  Bulding - Repairs / Maint.
#                                 5117  Bulding - Repairs / Maint.
#                                 5118  Bulding - Repairs / Maint.
#                                 5266  Bulding - Repairs / Maint.
#                                 5267  Bulding - Repairs / Maint.
#                                 5268  Bulding - Repairs / Maint.
#       Employee Benefits         394            Employee Benefits
#                                 395            Employee Benefits
#                                 396            Employee Benefits
#                                 397            Employee Benefits
#                                 398            Employee Benefits
#                                 399            Employee Benefits
#
#                                                  fdb_commonname         amtdb  \
# brnid fdb_commonname
# 200   Building Repair and Maint 5103  Building Repair and Maint      0.000000
#                                 5104  Building Repair and Maint      0.000000
#                                 5105  Building Repair and Maint     33.259998
#                                 5106  Building Repair and Maint     56.900002
#                                 5107  Building Repair and Maint     65.000000
#                                 5108  Building Repair and Maint    128.750000
#                                 5109  Building Repair and Maint    200.000000
#                                 5110  Building Repair and Maint    259.130005
#                                 5111  Building Repair and Maint   4470.649902
#                                 5112  Building Repair and Maint      0.000000
#                                 5113  Building Repair and Maint      0.000000
#                                 5114  Building Repair and Maint     10.950000
#                                 5115  Building Repair and Maint     34.000000
#                                 5116  Building Repair and Maint     99.000000
#                                 5117  Building Repair and Maint    288.750000
#                                 5118  Building Repair and Maint  13034.910156
#                                 5266  Building Repair and Maint      0.000000
#                                 5267  Building Repair and Maint     79.540001
#                                 5268  Building Repair and Maint    226.080002
#       Employee Benefits         394           Employee Benefits      0.000000
#                                 395           Employee Benefits      0.000000
#                                 396           Employee Benefits      0.000000
#                                 397           Employee Benefits      0.000000
#                                 398           Employee Benefits      0.000000
#                                 399           Employee Benefits      0.000000
#
#                                              amtcr    amtbalance
# brnid fdb_commonname
# 200   Building Repair and Maint 5103    259.130005   -259.130005
#                                 5104     33.259998    -33.259998
#                                 5105      0.000000     33.259998
#                                 5106      0.000000     56.900002
#                                 5107      0.000000     65.000000
#                                 5108      0.000000    128.750000
#                                 5109      0.000000    200.000000
#                                 5110      0.000000    259.130005
#                                 5111      0.000000   4470.649902
#                                 5112  13034.910156 -13034.910156
#                                 5113     34.000000    -34.000000
#                                 5114      0.000000     10.950000
#                                 5115      0.000000     34.000000
#                                 5116      0.000000     99.000000
#                                 5117      0.000000    288.750000
#                                 5118      0.000000  13034.910156
#                                 5266    305.619995   -305.619995
#                                 5267      0.000000     79.540001
#                                 5268      0.000000    226.080002
#       Employee Benefits         394   74987.750000 -74987.750000
#                                 395   70419.898438 -70419.898438
#                                 396   47671.949219 -47671.949219
#                                 397   35409.949219 -35409.949219
#                                 398   35009.949219 -35009.949219
#                                 399   30407.980469 -30407.980469

# %%
# Quick check about how many unique combination with brnid and fdb_commonname do we have in grouped
combination_check = df_1.groupby(['brnid', 'fdb_commonname']).size().reset_index()
# Print the result
print(combination_check)
# Out:
#      brnid             fdb_commonname     0
# 0      200  Building Repair and Maint    19
# 1      200          Employee Benefits  4772
# 2      200                 Rent/Lease   370
# 3      200                  Utilities    24
# 4      200           Vacation Expense   147
# ..     ...                        ...   ...
# 403    510           Delivery Expense   810
# 404    510          Employee Benefits   974
# 405    510                 Rent/Lease    36
# 406    510                  Utilities    81
# 407    510           Vacation Expense    25
#
# [408 rows x 3 columns]

# %% [markdown]
# #### Filtered_df and Detect the potential Anomalies

# %%
# Suppress the SettingWithCopyWarning
pd.options.mode.chained_assignment = None

# %%
# The goal is to check the anomaly for amtdb , amtcr, and amtbalance for each unique group. 

# I make a list to store all anomalies
all_anomalies = []

# Iterate through each unique combination of brnid and fdb_commonname
for _, row in combination_check.iterrows():
    brnid_value = row['brnid']
    fdb_commonname_value = row['fdb_commonname']
    
    # Filter the data for this specific combination
    df_filtered = grouped_df_1[(grouped_df_1['brnid'] == brnid_value) & 
                               (grouped_df_1['fdb_commonname'] == fdb_commonname_value)]
    
    print(f"Processing brnid: {brnid_value}, fdb_commonname: {fdb_commonname_value}")
    
    # Columns we want to look through
    columns = ['amtdb', 'amtcr', 'amtbalance']
    
    # Apply Isolation Forest for each column
    for column in columns:
        # Build isolation forest
        iso_forest = IsolationForest(contamination=0.00001, random_state=42)
        
        # Fit the model using the filtered data
        iso_forest.fit(df_filtered[[column]])
        
        # Predict anomalies (-1 indicates an anomaly, 1 indicates a normal point)
        anomaly_column = f'{column} Anomaly'  # Create a new column for anomaly detection
        df_filtered[anomaly_column] = iso_forest.predict(df_filtered[[column]])

    # If one of the three variables has -1 (anomaly), list the row
    result_filtered_detection = df_filtered[
        (df_filtered['amtdb Anomaly'] == -1) |
        (df_filtered['amtcr Anomaly'] == -1) |
        (df_filtered['amtbalance Anomaly'] == -1)
    ].reset_index(drop=True)
    
    # Append the result to the list of all anomalies
    if not result_filtered_detection.empty:
        all_anomalies.append(result_filtered_detection)
    
# Combine all results into a single DataFrame
combined_anomalies_df = pd.concat(all_anomalies, ignore_index=True)

# Display the combined result
print("Combined anomalies DataFrame:")
print(combined_anomalies_df)
# Out:
# Processing brnid: 200, fdb_commonname: Building Repair and Maint
# Processing brnid: 200, fdb_commonname: Employee Benefits
# Processing brnid: 200, fdb_commonname: Rent/Lease
# Processing brnid: 200, fdb_commonname: Utilities
# Processing brnid: 200, fdb_commonname: Vacation Expense
# Processing brnid: 210, fdb_commonname: Building Repair and Maint
# Processing brnid: 210, fdb_commonname: Delivery Expense
# Processing brnid: 210, fdb_commonname: Employee Benefits
# Processing brnid: 210, fdb_commonname: Policy Adjustments
# Processing brnid: 210, fdb_commonname: Rent/Lease
# Processing brnid: 210, fdb_commonname: Supplies - Collected
# Processing brnid: 210, fdb_commonname: Utilities
# Processing brnid: 210, fdb_commonname: Vacation Expense
# Processing brnid: 211, fdb_commonname: Building Repair and Maint
# Processing brnid: 211, fdb_commonname: Delivery Expense
# Processing brnid: 211, fdb_commonname: Employee Benefits
# Processing brnid: 211, fdb_commonname: Policy Adjustments
# Processing brnid: 211, fdb_commonname: Rent/Lease
# Processing brnid: 211, fdb_commonname: Utilities
# Processing brnid: 211, fdb_commonname: Vacation Expense
# Processing brnid: 220, fdb_commonname: Building Repair and Maint
# Processing brnid: 220, fdb_commonname: Delivery Expense
# Processing brnid: 220, fdb_commonname: Employee Benefits
# Processing brnid: 220, fdb_commonname: Policy Adjustments
# Processing brnid: 220, fdb_commonname: Rent/Lease
# Processing brnid: 220, fdb_commonname: Supplies - Collected
# Processing brnid: 220, fdb_commonname: Utilities
# Processing brnid: 220, fdb_commonname: Vacation Expense
# Processing brnid: 234, fdb_commonname: Building Repair and Maint
# Processing brnid: 234, fdb_commonname: Delivery Expense
# Processing brnid: 234, fdb_commonname: Employee Benefits
# Processing brnid: 234, fdb_commonname: Policy Adjustments
# Processing brnid: 234, fdb_commonname: Rent/Lease
# Processing brnid: 234, fdb_commonname: Utilities
# Processing brnid: 234, fdb_commonname: Vacation Expense
# Processing brnid: 235, fdb_commonname: Employee Benefits
# Processing brnid: 235, fdb_commonname: Vacation Expense
# Processing brnid: 240, fdb_commonname: Building Repair and Maint
# Processing brnid: 240, fdb_commonname: Delivery Expense
# Processing brnid: 240, fdb_commonname: Employee Benefits
# Processing brnid: 240, fdb_commonname: Policy Adjustments
# Processing brnid: 240, fdb_commonname: Rent/Lease
# Processing brnid: 240, fdb_commonname: Supplies - Collected
# Processing brnid: 240, fdb_commonname: Utilities
# Processing brnid: 240, fdb_commonname: Vacation Expense
# Processing brnid: 241, fdb_commonname: Building Repair and Maint
# Processing brnid: 241, fdb_commonname: Delivery Expense
# Processing brnid: 241, fdb_commonname: Employee Benefits
# Processing brnid: 241, fdb_commonname: Policy Adjustments
# Processing brnid: 241, fdb_commonname: Rent/Lease
# Processing brnid: 241, fdb_commonname: Supplies - Collected
# Processing brnid: 241, fdb_commonname: Utilities
# Processing brnid: 241, fdb_commonname: Vacation Expense
# Processing brnid: 242, fdb_commonname: Building Repair and Maint
# Processing brnid: 242, fdb_commonname: Delivery Expense
# Processing brnid: 242, fdb_commonname: Employee Benefits
# Processing brnid: 242, fdb_commonname: Policy Adjustments
# Processing brnid: 242, fdb_commonname: Rent/Lease
# Processing brnid: 242, fdb_commonname: Supplies - Collected
# Processing brnid: 242, fdb_commonname: Utilities
# Processing brnid: 242, fdb_commonname: Vacation Expense
# Processing brnid: 250, fdb_commonname: Building Repair and Maint
# Processing brnid: 250, fdb_commonname: Delivery Expense
# Processing brnid: 250, fdb_commonname: Employee Benefits
# Processing brnid: 250, fdb_commonname: Rent/Lease
# Processing brnid: 250, fdb_commonname: Utilities
# Processing brnid: 250, fdb_commonname: Vacation Expense
# Processing brnid: 260, fdb_commonname: Building Repair and Maint
# Processing brnid: 260, fdb_commonname: Delivery Expense
# Processing brnid: 260, fdb_commonname: Employee Benefits
# Processing brnid: 260, fdb_commonname: Policy Adjustments
# Processing brnid: 260, fdb_commonname: Rent/Lease
# Processing brnid: 260, fdb_commonname: Supplies - Collected
# Processing brnid: 260, fdb_commonname: Utilities
# Processing brnid: 260, fdb_commonname: Vacation Expense
# Processing brnid: 261, fdb_commonname: Building Repair and Maint
# Processing brnid: 261, fdb_commonname: Delivery Expense
# Processing brnid: 261, fdb_commonname: Employee Benefits
# Processing brnid: 261, fdb_commonname: Policy Adjustments
# Processing brnid: 261, fdb_commonname: Rent/Lease
# Processing brnid: 261, fdb_commonname: Supplies - Collected
# Processing brnid: 261, fdb_commonname: Utilities
# Processing brnid: 261, fdb_commonname: Vacation Expense
# Processing brnid: 270, fdb_commonname: Building Repair and Maint
# Processing brnid: 270, fdb_commonname: Delivery Expense
# Processing brnid: 270, fdb_commonname: Employee Benefits
# Processing brnid: 270, fdb_commonname: Policy Adjustments
# Processing brnid: 270, fdb_commonname: Rent/Lease
# Processing brnid: 270, fdb_commonname: Supplies - Collected
# Processing brnid: 270, fdb_commonname: Utilities
# Processing brnid: 270, fdb_commonname: Vacation Expense
# Processing brnid: 274, fdb_commonname: Building Repair and Maint
# Processing brnid: 274, fdb_commonname: Delivery Expense
# Processing brnid: 274, fdb_commonname: Employee Benefits
# Processing brnid: 274, fdb_commonname: Policy Adjustments
# Processing brnid: 274, fdb_commonname: Rent/Lease
# Processing brnid: 274, fdb_commonname: Utilities
# Processing brnid: 274, fdb_commonname: Vacation Expense
# Processing brnid: 275, fdb_commonname: Building Repair and Maint
# Processing brnid: 275, fdb_commonname: Delivery Expense
# Processing brnid: 275, fdb_commonname: Employee Benefits
# Processing brnid: 275, fdb_commonname: Rent/Lease
# Processing brnid: 275, fdb_commonname: Utilities
# Processing brnid: 275, fdb_commonname: Vacation Expense
# Processing brnid: 276, fdb_commonname: Building Repair and Maint
# Processing brnid: 276, fdb_commonname: Delivery Expense
# Processing brnid: 276, fdb_commonname: Employee Benefits
# Processing brnid: 276, fdb_commonname: Policy Adjustments
# Processing brnid: 276, fdb_commonname: Rent/Lease
# Processing brnid: 276, fdb_commonname: Utilities
# Processing brnid: 276, fdb_commonname: Vacation Expense
# Processing brnid: 277, fdb_commonname: Building Repair and Maint
# Processing brnid: 277, fdb_commonname: Delivery Expense
# Processing brnid: 277, fdb_commonname: Employee Benefits
# Processing brnid: 277, fdb_commonname: Rent/Lease
# Processing brnid: 277, fdb_commonname: Utilities
# Processing brnid: 277, fdb_commonname: Vacation Expense
# Processing brnid: 278, fdb_commonname: Building Repair and Maint
# Processing brnid: 278, fdb_commonname: Delivery Expense
# Processing brnid: 278, fdb_commonname: Employee Benefits
# Processing brnid: 278, fdb_commonname: Policy Adjustments
# Processing brnid: 278, fdb_commonname: Rent/Lease
# Processing brnid: 278, fdb_commonname: Utilities
# Processing brnid: 278, fdb_commonname: Vacation Expense
# Processing brnid: 279, fdb_commonname: Building Repair and Maint
# Processing brnid: 279, fdb_commonname: Delivery Expense
# Processing brnid: 279, fdb_commonname: Employee Benefits
# Processing brnid: 279, fdb_commonname: Policy Adjustments
# Processing brnid: 279, fdb_commonname: Rent/Lease
# Processing brnid: 279, fdb_commonname: Utilities
# Processing brnid: 279, fdb_commonname: Vacation Expense
# Processing brnid: 290, fdb_commonname: Building Repair and Maint
# Processing brnid: 290, fdb_commonname: Delivery Expense
# Processing brnid: 290, fdb_commonname: Employee Benefits
# Processing brnid: 290, fdb_commonname: Policy Adjustments
# Processing brnid: 290, fdb_commonname: Rent/Lease
# Processing brnid: 290, fdb_commonname: Supplies - Collected
# Processing brnid: 290, fdb_commonname: Utilities
# Processing brnid: 290, fdb_commonname: Vacation Expense
# Processing brnid: 292, fdb_commonname: Building Repair and Maint
# Processing brnid: 292, fdb_commonname: Delivery Expense
# Processing brnid: 292, fdb_commonname: Employee Benefits
# Processing brnid: 292, fdb_commonname: Policy Adjustments
# Processing brnid: 292, fdb_commonname: Rent/Lease
# Processing brnid: 292, fdb_commonname: Utilities
# Processing brnid: 292, fdb_commonname: Vacation Expense
# Processing brnid: 293, fdb_commonname: Building Repair and Maint
# Processing brnid: 293, fdb_commonname: Delivery Expense
# Processing brnid: 293, fdb_commonname: Employee Benefits
# Processing brnid: 293, fdb_commonname: Policy Adjustments
# Processing brnid: 293, fdb_commonname: Rent/Lease
# Processing brnid: 293, fdb_commonname: Supplies - Collected
# Processing brnid: 293, fdb_commonname: Utilities
# Processing brnid: 293, fdb_commonname: Vacation Expense
# Processing brnid: 297, fdb_commonname: Employee Benefits
# Processing brnid: 297, fdb_commonname: Rent/Lease
# Processing brnid: 297, fdb_commonname: Utilities
# Processing brnid: 298, fdb_commonname: Employee Benefits
# Processing brnid: 298, fdb_commonname: Rent/Lease
# Processing brnid: 300, fdb_commonname: Building Repair and Maint
# Processing brnid: 300, fdb_commonname: Employee Benefits
# Processing brnid: 300, fdb_commonname: Rent/Lease
# Processing brnid: 310, fdb_commonname: Building Repair and Maint
# Processing brnid: 310, fdb_commonname: Delivery Expense
# Processing brnid: 310, fdb_commonname: Employee Benefits
# Processing brnid: 310, fdb_commonname: Policy Adjustments
# Processing brnid: 310, fdb_commonname: Rent/Lease
# Processing brnid: 310, fdb_commonname: Supplies - Collected
# Processing brnid: 310, fdb_commonname: Utilities
# Processing brnid: 310, fdb_commonname: Vacation Expense
# Processing brnid: 320, fdb_commonname: Building Repair and Maint
# Processing brnid: 320, fdb_commonname: Delivery Expense
# Processing brnid: 320, fdb_commonname: Employee Benefits
# Processing brnid: 320, fdb_commonname: Policy Adjustments
# Processing brnid: 320, fdb_commonname: Rent/Lease
# Processing brnid: 320, fdb_commonname: Supplies - Collected
# Processing brnid: 320, fdb_commonname: Utilities
# Processing brnid: 320, fdb_commonname: Vacation Expense
# Processing brnid: 330, fdb_commonname: Building Repair and Maint
# Processing brnid: 330, fdb_commonname: Employee Benefits
# Processing brnid: 330, fdb_commonname: Policy Adjustments
# Processing brnid: 330, fdb_commonname: Rent/Lease
# Processing brnid: 330, fdb_commonname: Supplies - Collected
# Processing brnid: 330, fdb_commonname: Utilities
# Processing brnid: 330, fdb_commonname: Vacation Expense
# Processing brnid: 340, fdb_commonname: Building Repair and Maint
# Processing brnid: 340, fdb_commonname: Delivery Expense
# Processing brnid: 340, fdb_commonname: Employee Benefits
# Processing brnid: 340, fdb_commonname: Policy Adjustments
# Processing brnid: 340, fdb_commonname: Rent/Lease
# Processing brnid: 340, fdb_commonname: Supplies - Collected
# Processing brnid: 340, fdb_commonname: Utilities
# Processing brnid: 340, fdb_commonname: Vacation Expense
# Processing brnid: 350, fdb_commonname: Building Repair and Maint
# Processing brnid: 350, fdb_commonname: Delivery Expense
# Processing brnid: 350, fdb_commonname: Employee Benefits
# Processing brnid: 350, fdb_commonname: Policy Adjustments
# Processing brnid: 350, fdb_commonname: Rent/Lease
# Processing brnid: 350, fdb_commonname: Utilities
# Processing brnid: 350, fdb_commonname: Vacation Expense
# Processing brnid: 355, fdb_commonname: Building Repair and Maint
# Processing brnid: 355, fdb_commonname: Delivery Expense
# Processing brnid: 355, fdb_commonname: Employee Benefits
# Processing brnid: 355, fdb_commonname: Policy Adjustments
# Processing brnid: 355, fdb_commonname: Rent/Lease
# Processing brnid: 355, fdb_commonname: Supplies - Collected
# Processing brnid: 355, fdb_commonname: Utilities
# Processing brnid: 355, fdb_commonname: Vacation Expense
# Processing brnid: 360, fdb_commonname: Building Repair and Maint
# Processing brnid: 360, fdb_commonname: Delivery Expense
# Processing brnid: 360, fdb_commonname: Employee Benefits
# Processing brnid: 360, fdb_commonname: Policy Adjustments
# Processing brnid: 360, fdb_commonname: Rent/Lease
# Processing brnid: 360, fdb_commonname: Supplies - Collected
# Processing brnid: 360, fdb_commonname: Utilities
# Processing brnid: 360, fdb_commonname: Vacation Expense
# Processing brnid: 361, fdb_commonname: Building Repair and Maint
# Processing brnid: 361, fdb_commonname: Delivery Expense
# Processing brnid: 361, fdb_commonname: Employee Benefits
# Processing brnid: 361, fdb_commonname: Policy Adjustments
# Processing brnid: 361, fdb_commonname: Rent/Lease
# Processing brnid: 361, fdb_commonname: Supplies - Collected
# Processing brnid: 361, fdb_commonname: Utilities
# Processing brnid: 361, fdb_commonname: Vacation Expense
# Processing brnid: 362, fdb_commonname: Building Repair and Maint
# Processing brnid: 362, fdb_commonname: Delivery Expense
# Processing brnid: 362, fdb_commonname: Employee Benefits
# Processing brnid: 362, fdb_commonname: Policy Adjustments
# Processing brnid: 362, fdb_commonname: Rent/Lease
# Processing brnid: 362, fdb_commonname: Supplies - Collected
# Processing brnid: 362, fdb_commonname: Utilities
# Processing brnid: 362, fdb_commonname: Vacation Expense
# Processing brnid: 363, fdb_commonname: Building Repair and Maint
# Processing brnid: 363, fdb_commonname: Delivery Expense
# Processing brnid: 363, fdb_commonname: Employee Benefits
# Processing brnid: 363, fdb_commonname: Policy Adjustments
# Processing brnid: 363, fdb_commonname: Rent/Lease
# Processing brnid: 363, fdb_commonname: Supplies - Collected
# Processing brnid: 363, fdb_commonname: Utilities
# Processing brnid: 363, fdb_commonname: Vacation Expense
# Processing brnid: 364, fdb_commonname: Building Repair and Maint
# Processing brnid: 364, fdb_commonname: Delivery Expense
# Processing brnid: 364, fdb_commonname: Employee Benefits
# Processing brnid: 364, fdb_commonname: Policy Adjustments
# Processing brnid: 364, fdb_commonname: Rent/Lease
# Processing brnid: 364, fdb_commonname: Supplies - Collected
# Processing brnid: 364, fdb_commonname: Utilities
# Processing brnid: 364, fdb_commonname: Vacation Expense
# Processing brnid: 365, fdb_commonname: Building Repair and Maint
# Processing brnid: 365, fdb_commonname: Delivery Expense
# Processing brnid: 365, fdb_commonname: Employee Benefits
# Processing brnid: 365, fdb_commonname: Policy Adjustments
# Processing brnid: 365, fdb_commonname: Rent/Lease
# Processing brnid: 365, fdb_commonname: Supplies - Collected
# Processing brnid: 365, fdb_commonname: Utilities
# Processing brnid: 365, fdb_commonname: Vacation Expense
# Processing brnid: 366, fdb_commonname: Building Repair and Maint
# Processing brnid: 366, fdb_commonname: Delivery Expense
# Processing brnid: 366, fdb_commonname: Employee Benefits
# Processing brnid: 366, fdb_commonname: Policy Adjustments
# Processing brnid: 366, fdb_commonname: Rent/Lease
# Processing brnid: 366, fdb_commonname: Supplies - Collected
# Processing brnid: 366, fdb_commonname: Utilities
# Processing brnid: 366, fdb_commonname: Vacation Expense
# Processing brnid: 367, fdb_commonname: Building Repair and Maint
# Processing brnid: 367, fdb_commonname: Delivery Expense
# Processing brnid: 367, fdb_commonname: Employee Benefits
# Processing brnid: 367, fdb_commonname: Policy Adjustments
# Processing brnid: 367, fdb_commonname: Rent/Lease
# Processing brnid: 367, fdb_commonname: Supplies - Collected
# Processing brnid: 367, fdb_commonname: Utilities
# Processing brnid: 367, fdb_commonname: Vacation Expense
# Processing brnid: 368, fdb_commonname: Building Repair and Maint
# Processing brnid: 368, fdb_commonname: Delivery Expense
# Processing brnid: 368, fdb_commonname: Employee Benefits
# Processing brnid: 368, fdb_commonname: Policy Adjustments
# Processing brnid: 368, fdb_commonname: Supplies - Collected
# Processing brnid: 368, fdb_commonname: Utilities
# Processing brnid: 368, fdb_commonname: Vacation Expense
# Processing brnid: 369, fdb_commonname: Building Repair and Maint
# Processing brnid: 369, fdb_commonname: Employee Benefits
# Processing brnid: 369, fdb_commonname: Policy Adjustments
# Processing brnid: 369, fdb_commonname: Rent/Lease
# Processing brnid: 369, fdb_commonname: Supplies - Collected
# Processing brnid: 369, fdb_commonname: Utilities
# Processing brnid: 369, fdb_commonname: Vacation Expense
# Processing brnid: 370, fdb_commonname: Building Repair and Maint
# Processing brnid: 370, fdb_commonname: Delivery Expense
# Processing brnid: 370, fdb_commonname: Employee Benefits
# Processing brnid: 370, fdb_commonname: Policy Adjustments
# Processing brnid: 370, fdb_commonname: Rent/Lease
# Processing brnid: 370, fdb_commonname: Supplies - Collected
# Processing brnid: 370, fdb_commonname: Utilities
# Processing brnid: 370, fdb_commonname: Vacation Expense
# Processing brnid: 372, fdb_commonname: Building Repair and Maint
# Processing brnid: 372, fdb_commonname: Delivery Expense
# Processing brnid: 372, fdb_commonname: Employee Benefits
# Processing brnid: 372, fdb_commonname: Policy Adjustments
# Processing brnid: 372, fdb_commonname: Rent/Lease
# Processing brnid: 372, fdb_commonname: Supplies - Collected
# Processing brnid: 372, fdb_commonname: Utilities
# Processing brnid: 372, fdb_commonname: Vacation Expense
# Processing brnid: 373, fdb_commonname: Building Repair and Maint
# Processing brnid: 373, fdb_commonname: Employee Benefits
# Processing brnid: 373, fdb_commonname: Policy Adjustments
# Processing brnid: 373, fdb_commonname: Rent/Lease
# Processing brnid: 373, fdb_commonname: Supplies - Collected
# Processing brnid: 373, fdb_commonname: Utilities
# Processing brnid: 373, fdb_commonname: Vacation Expense
# Processing brnid: 374, fdb_commonname: Building Repair and Maint
# Processing brnid: 374, fdb_commonname: Delivery Expense
# Processing brnid: 374, fdb_commonname: Employee Benefits
# Processing brnid: 374, fdb_commonname: Policy Adjustments
# Processing brnid: 374, fdb_commonname: Rent/Lease
# Processing brnid: 374, fdb_commonname: Supplies - Collected
# Processing brnid: 374, fdb_commonname: Utilities
# Processing brnid: 374, fdb_commonname: Vacation Expense
# Processing brnid: 380, fdb_commonname: Building Repair and Maint
# Processing brnid: 380, fdb_commonname: Delivery Expense
# Processing brnid: 380, fdb_commonname: Employee Benefits
# Processing brnid: 380, fdb_commonname: Policy Adjustments
# Processing brnid: 380, fdb_commonname: Rent/Lease
# Processing brnid: 380, fdb_commonname: Supplies - Collected
# Processing brnid: 380, fdb_commonname: Utilities
# Processing brnid: 380, fdb_commonname: Vacation Expense
# Processing brnid: 381, fdb_commonname: Building Repair and Maint
# Processing brnid: 381, fdb_commonname: Employee Benefits
# Processing brnid: 381, fdb_commonname: Policy Adjustments
# Processing brnid: 381, fdb_commonname: Rent/Lease
# Processing brnid: 381, fdb_commonname: Supplies - Collected
# Processing brnid: 381, fdb_commonname: Utilities
# Processing brnid: 381, fdb_commonname: Vacation Expense
# Processing brnid: 390, fdb_commonname: Building Repair and Maint
# Processing brnid: 390, fdb_commonname: Delivery Expense
# Processing brnid: 390, fdb_commonname: Employee Benefits
# Processing brnid: 390, fdb_commonname: Policy Adjustments
# Processing brnid: 390, fdb_commonname: Rent/Lease
# Processing brnid: 390, fdb_commonname: Supplies - Collected
# Processing brnid: 390, fdb_commonname: Utilities
# Processing brnid: 390, fdb_commonname: Vacation Expense
# Processing brnid: 391, fdb_commonname: Building Repair and Maint
# Processing brnid: 391, fdb_commonname: Delivery Expense
# Processing brnid: 391, fdb_commonname: Employee Benefits
# Processing brnid: 391, fdb_commonname: Policy Adjustments
# Processing brnid: 391, fdb_commonname: Rent/Lease
# Processing brnid: 391, fdb_commonname: Supplies - Collected
# Processing brnid: 391, fdb_commonname: Utilities
# Processing brnid: 391, fdb_commonname: Vacation Expense
# Processing brnid: 395, fdb_commonname: Building Repair and Maint
# Processing brnid: 395, fdb_commonname: Delivery Expense
# Processing brnid: 395, fdb_commonname: Employee Benefits
# Processing brnid: 395, fdb_commonname: Policy Adjustments
# Processing brnid: 395, fdb_commonname: Rent/Lease
# Processing brnid: 395, fdb_commonname: Supplies - Collected
# Processing brnid: 395, fdb_commonname: Utilities
# Processing brnid: 395, fdb_commonname: Vacation Expense
# Processing brnid: 396, fdb_commonname: Building Repair and Maint
# Processing brnid: 396, fdb_commonname: Delivery Expense
# Processing brnid: 396, fdb_commonname: Employee Benefits
# Processing brnid: 396, fdb_commonname: Policy Adjustments
# Processing brnid: 396, fdb_commonname: Rent/Lease
# Processing brnid: 396, fdb_commonname: Supplies - Collected
# Processing brnid: 396, fdb_commonname: Utilities
# Processing brnid: 396, fdb_commonname: Vacation Expense
# Processing brnid: 397, fdb_commonname: Building Repair and Maint
# Processing brnid: 397, fdb_commonname: Delivery Expense
# Processing brnid: 397, fdb_commonname: Employee Benefits
# Processing brnid: 397, fdb_commonname: Policy Adjustments
# Processing brnid: 397, fdb_commonname: Rent/Lease
# Processing brnid: 397, fdb_commonname: Supplies - Collected
# Processing brnid: 397, fdb_commonname: Utilities
# Processing brnid: 397, fdb_commonname: Vacation Expense
# Processing brnid: 398, fdb_commonname: Building Repair and Maint
# Processing brnid: 398, fdb_commonname: Employee Benefits
# Processing brnid: 398, fdb_commonname: Policy Adjustments
# Processing brnid: 398, fdb_commonname: Rent/Lease
# Processing brnid: 398, fdb_commonname: Supplies - Collected
# Processing brnid: 398, fdb_commonname: Utilities
# Processing brnid: 398, fdb_commonname: Vacation Expense
# Processing brnid: 400, fdb_commonname: Building Repair and Maint
# Processing brnid: 400, fdb_commonname: Delivery Expense
# Processing brnid: 400, fdb_commonname: Employee Benefits
# Processing brnid: 400, fdb_commonname: Policy Adjustments
# Processing brnid: 400, fdb_commonname: Rent/Lease
# Processing brnid: 400, fdb_commonname: Utilities
# Processing brnid: 400, fdb_commonname: Vacation Expense
# Processing brnid: 410, fdb_commonname: Building Repair and Maint
# Processing brnid: 410, fdb_commonname: Delivery Expense
# Processing brnid: 410, fdb_commonname: Employee Benefits
# Processing brnid: 410, fdb_commonname: Policy Adjustments
# Processing brnid: 410, fdb_commonname: Rent/Lease
# Processing brnid: 410, fdb_commonname: Supplies - Collected
# Processing brnid: 410, fdb_commonname: Utilities
# Processing brnid: 410, fdb_commonname: Vacation Expense
# Processing brnid: 500, fdb_commonname: Building Repair and Maint
# Processing brnid: 500, fdb_commonname: Delivery Expense
# Processing brnid: 500, fdb_commonname: Employee Benefits
# Processing brnid: 500, fdb_commonname: Policy Adjustments
# Processing brnid: 500, fdb_commonname: Rent/Lease
# Processing brnid: 500, fdb_commonname: Supplies - Collected
# Processing brnid: 500, fdb_commonname: Utilities
# Processing brnid: 500, fdb_commonname: Vacation Expense
# Processing brnid: 510, fdb_commonname: Building Repair and Maint
# Processing brnid: 510, fdb_commonname: Delivery Expense
# Processing brnid: 510, fdb_commonname: Employee Benefits
# Processing brnid: 510, fdb_commonname: Rent/Lease
# Processing brnid: 510, fdb_commonname: Utilities
# Processing brnid: 510, fdb_commonname: Vacation Expense
# Combined anomalies DataFrame:
#           date  year  month  brnid          brnmisc7        department  \
# 0   2024-04-30  2024      4    200    Corporate LATC         Corporate
# 1   2024-04-30  2024      4    200    Corporate LATC         Corporate
# 2   2023-09-30  2023      9    200    Corporate LATC         Corporate
# 3   2024-04-30  2024      4    200    Corporate LATC         Corporate
# 4   2024-03-31  2024      3    200    Corporate LATC         Corporate
# ..         ...   ...    ...    ...               ...               ...
# 619 2024-02-29  2024      2    510  Great Dane (510)  Used Truck Sales
# 620 2024-05-31  2024      5    510  Great Dane (510)  Used Truck Sales
# 621 2024-05-31  2024      5    510  Great Dane (510)  Used Truck Sales
# 622 2024-01-31  2024      1    510  Great Dane (510)   New Truck Sales
# 623 2023-02-28  2023      2    510  Great Dane (510)  Used Truck Sales
#
#               altdept     type typ_text    category  \
# 0           Corporate  Expense  Expense  Semi-Fixed
# 1           Corporate  Expense  Expense  Semi-Fixed
# 2           Corporate  Expense  Expense   Personnel
# 3           Corporate  Expense  Expense       Fixed
# 4           Corporate  Expense  Expense       Fixed
# ..                ...      ...      ...         ...
# 619  Used Truck Sales  Expense  Expense  Semi-Fixed
# 620  Used Truck Sales  Expense  Expense   Personnel
# 621  Used Truck Sales  Expense  Expense   Personnel
# 622  Used Truck Sales  Expense  Expense   Personnel
# 623  Used Truck Sales  Expense  Expense   Personnel
#
#                     subcategory             fdb_commonname         amtdb  \
# 0    Bulding - Repairs / Maint.  Building Repair and Maint      0.000000
# 1    Bulding - Repairs / Maint.  Building Repair and Maint  13034.910156
# 2             Employee Benefits          Employee Benefits  71639.101562
# 3                  Rent / Lease                 Rent/Lease      0.000000
# 4                  Rent / Lease                 Rent/Lease  29418.269531
# ..                          ...                        ...           ...
# 619  Bulding - Repairs / Maint.  Building Repair and Maint      0.000000
# 620           Employee Benefits          Employee Benefits      0.000000
# 621           Employee Benefits          Employee Benefits   5468.750000
# 622           Employee Benefits           Vacation Expense     19.090000
# 623           Employee Benefits           Vacation Expense      0.000000
#
#             amtcr    amtbalance  amtdb Anomaly  amtcr Anomaly  \
# 0    13034.910156 -13034.910156              1             -1
# 1        0.000000  13034.910156             -1              1
# 2        0.000000  71639.101562             -1              1
# 3    29418.269531 -29418.269531              1             -1
# 4        0.000000  29418.269531             -1              1
# ..            ...           ...            ...            ...
# 619      0.040000     -0.040000              1             -1
# 620   5468.750000  -5468.750000              1             -1
# 621      0.000000   5468.750000             -1              1
# 622      0.000000     19.090000             -1              1
# 623    718.570007   -718.570007              1             -1
#
#      amtbalance Anomaly
# 0                    -1
# 1                     1
# 2                     1
# 3                    -1
# 4                     1
# ..                  ...
# 619                   1
# 620                  -1
# 621                   1
# 622                   1
# 623                  -1
#
# [624 rows x 18 columns]

# %%
# Filter and group for 'amtdb Anomaly'
amtdb_anomaly_df = combined_anomalies_df[combined_anomalies_df['amtdb Anomaly'] == -1].reset_index(drop=True)
print("AMTDB Anomaly DataFrame shape:", amtdb_anomaly_df.shape)
grouped_counts_amtdb = amtdb_anomaly_df.groupby(['year', 'month']).size().reset_index(name='count')
print("Grouped Counts for AMTDB Anomaly:")
print(grouped_counts_amtdb)

# Filter and group for 'amtcr Anomaly'
amtcr_anomaly_df = combined_anomalies_df[combined_anomalies_df['amtcr Anomaly'] == -1].reset_index(drop=True)
print("AMTCR Anomaly DataFrame shape:", amtcr_anomaly_df.shape)
grouped_counts_amtcr = amtcr_anomaly_df.groupby(['year', 'month']).size().reset_index(name='count')
print("Grouped Counts for AMTCR Anomaly:")
print(grouped_counts_amtcr)

# Filter and group for 'amtbalance Anomaly'
amtbalance_anomaly_df = combined_anomalies_df[combined_anomalies_df['amtbalance Anomaly'] == -1].reset_index(drop=True)
print("AMTBALANCE Anomaly DataFrame shape:", amtbalance_anomaly_df.shape)
grouped_counts_amtbalance = amtbalance_anomaly_df.groupby(['year', 'month']).size().reset_index(name='count')
print("Grouped Counts for AMTBALANCE Anomaly:")
print(grouped_counts_amtbalance)
# Out:
# AMTDB Anomaly DataFrame shape: (307, 18)
# Grouped Counts for AMTDB Anomaly:
#     year  month  count
# 0   2023      1     41
# 1   2023      2      8
# 2   2023      3     10
# 3   2023      4     13
# 4   2023      5     13
# 5   2023      6     12
# 6   2023      7      6
# 7   2023      8     17
# 8   2023      9     10
# 9   2023     10      4
# 10  2023     11     10
# 11  2023     12     13
# 12  2024      1     15
# 13  2024      2     28
# 14  2024      3     22
# 15  2024      4     20
# 16  2024      5     21
# 17  2024      6     44
# AMTCR Anomaly DataFrame shape: (307, 18)
# Grouped Counts for AMTCR Anomaly:
#     year  month  count
# 0   2023      1      8
# 1   2023      2     32
# 2   2023      3     21
# 3   2023      4      9
# 4   2023      5     10
# 5   2023      6     12
# 6   2023      7      6
# 7   2023      8     12
# 8   2023      9      8
# 9   2023     10      3
# 10  2023     11      9
# 11  2023     12      9
# 12  2024      1     16
# 13  2024      2     54
# 14  2024      3     28
# 15  2024      4     18
# 16  2024      5     31
# 17  2024      6     21
# AMTBALANCE Anomaly DataFrame shape: (320, 18)
# Grouped Counts for AMTBALANCE Anomaly:
#     year  month  count
# 0   2023      1     21
# 1   2023      2     29
# 2   2023      3     15
# 3   2023      4     18
# 4   2023      5     12
# 5   2023      6     12
# 6   2023      7      8
# 7   2023      8     16
# 8   2023      9     10
# 9   2023     10      1
# 10  2023     11     10
# 11  2023     12     10
# 12  2024      1     16
# 13  2024      2     41
# 14  2024      3     32
# 15  2024      4     19
# 16  2024      5     24
# 17  2024      6     26
